# %%
from pathlib import Path
import json
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
# %matplotlib inline
import torchtext
from torchtext.data import get_tokenizer
from collections import Counter

from torch_geometric.nn import FastRGCNConv, RGCNConv
from torch_geometric.utils import k_hop_subgraph


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def flatten(list_of_list):
    return [item for sublist in list_of_list for item in sublist]

path_to_training = Path("training")
path_to_test = Path("test")

# Training and test sets of transcription ids
training_set = ['ES2002', 'ES2005', 'ES2006', 'ES2007', 'ES2008', 'ES2009', 'ES2010', 'ES2012', 'ES2013', 'ES2015', 'ES2016', 'IS1000', 'IS1001', 'IS1002', 'IS1003', 'IS1004', 'IS1005', 'IS1006', 'IS1007', 'TS3005', 'TS3008', 'TS3009', 'TS3010', 'TS3011', 'TS3012']
training_set = flatten([[m_id+s_id for s_id in 'abcd'] for m_id in training_set])
training_set.remove('IS1002a')
training_set.remove('IS1005d')
training_set.remove('TS3012c')

test_set = ['ES2003', 'ES2004', 'ES2011', 'ES2014', 'IS1008', 'IS1009', 'TS3003', 'TS3004', 'TS3006', 'TS3007']
test_set = flatten([[m_id+s_id for s_id in 'abcd'] for m_id in test_set])

possible_speakers = ["ID", "ME", "PM", "UI"]

# we add the 'Beginning' possibility
possible_types = ['Beginning', 'Question-answer_pair', 'Clarification_question', 'Continuation', 'Elaboration', 'Explanation', 'Narration', 'Comment', 'Contrast', 'Conditional', 'Result', 'Acknowledgement', 'Parallel', 'Q-Elab', 'Correction', 'Alternation', 'Background']


y_training = []
with open("training_labels.json", "r") as file:
    training_labels = json.load(file)

# we collect the useful data independantly for each dialog
dialogs_dataset = []

# we collect the maximal size of a dialog to have only one batch every time
max_batch_size = 0

for transcription_id in training_set:
    utterances = []
    speakers = []
    types = []
    index = []
    transcription_edges = []
    with open(path_to_training / f"{transcription_id}.txt", 'r') as file:
        transcription_edges.append("0 Beginning 0\n")
        for line in file:
            transcription_edges.append(line)
    tmp_types = [d.split(" ")[1] for d in transcription_edges]
    tmp_edges_start = [int(d.split(" ")[0]) for d in transcription_edges]
    tmp_edges_end = [int(d.split(" ")[2][:-1]) for d in transcription_edges]
    edges = [tmp_edges_start, tmp_edges_end]
    
    types_ori = [[1*(t==tmp_t) for t in possible_types] for tmp_t in tmp_types]
    types = [possible_types.index(tmp_t) for tmp_t in tmp_types]

    with open(path_to_training / f"{transcription_id}.json", "r") as file:
        transcription = json.load(file)
    
    for utterance in transcription:
        speakers.append([1*(speaker==utterance["speaker"]) for speaker in possible_speakers])
        utterances.append(utterance["text"])
        index.append([utterance["index"]])

    max_batch_size = max(max_batch_size, len(utterances))
    index = np.array(index)/len(index)
    
    y_training.append(training_labels[transcription_id])

    dialogs_dataset.append([utterances, types_ori, types, speakers, index, edges])

# %%
X_train, X_val, y_train, y_val = train_test_split(dialogs_dataset, y_training, test_size=0.2)

# %%
tokenizer = get_tokenizer("basic_english")

# build vocabulary and sometimes select the most frequent words
words=[]
num_words = 5000

# we tried unsuccessfully to remove the punctuation and the words of one letter
for dialog in X_train:
    for utterance in dialog[0]:
        tokens=tokenizer(utterance)
        # clean_tokens = []
        # for token in tokens:
        #     if(len(token) > 1):
        #         clean_tokens.append(token)
        # words.extend(clean_tokens)
        words.extend(tokens)

for dialog in X_val:
    for utterance in dialog[0]:
        tokens=tokenizer(utterance)
        # clean_tokens = []
        # for token in tokens:
        #     if(len(token) > 1):
        #         clean_tokens.append(token)
        # words.extend(clean_tokens)
        words.extend(tokens)

for transcription_id in test_set:
    with open(path_to_test / f"{transcription_id}.json", "r") as file:
        transcription = json.load(file)
    for utterance in transcription:
        tokens=tokenizer(utterance["text"])
        # clean_tokens = []
        # for token in tokens:
        #     if(len(token) > 1):
        #         clean_tokens.append(token)
        # words.extend(clean_tokens)
        words.extend(tokens)

# tops = dict(Counter(words).most_common(num_words))
tops = dict(Counter(words))

print(tops)
print(len(tops))

vocab = torchtext.vocab.vocab(tops, specials = ['<unk>', '<pad>'])
vocab.set_default_index(vocab['<unk>']) # default index used when an unknown words is found

print(X_train[0][0][0])
print(vocab.forward(tokenizer(X_train[0][0][0]))) # example of how a sentence is transformed into a sequence of numerical IDs
# Out:
# {'<vocalsound>': 13172, 'okay': 7360, '.': 64349, 'oh': 2147, 'i': 18625, 'totally': 66, '<disfmarker>': 16655, 'yeah': 18779, "'": 28944, 'cause': 801, 'moved': 7, 'it': 21253, 's': 14710, 'put': 1079, 'over': 358, 'here': 1197, 'then': 3197, 'we': 15526, 'don': 2670, 't': 5572, 'have': 7843, 'to': 15097, 'worry': 48, 'about': 2247, 'ready': 87, 'for': 5198, 'this': 4697, '?': 7005, 'all': 1949, 'set': 191, 'cool': 385, 'alright': 658, ',': 39568, 'is': 7430, 'powerpoint': 94, 'time': 801, 've': 1592, 'done': 296, 'more': 1923, 'powerpoints': 4, 'in': 5556, 'particular': 78, 'experiment': 10, 'than': 681, 'ever': 58, 'my': 1138, 'life': 33, 'before': 269, 'which': 1560, 'kind': 1248, 'of': 9138, 'fun': 94, 'man': 38, 'so': 10487, 'uh': 19082, 'our': 1825, 'detailed': 62, 'design': 1427, 'meeting': 798, 'where': 675, 'will': 1793, 'um': 8936, 'look': 1135, 'at': 1680, 'the': 30119, 'prototype': 190, 'and': 14645, 'right': 2107, 'finally': 49, 'figured': 32, 'out': 970, 'what': 4185, 'whole': 246, 'second': 224, 'bullet': 6, 'point': 690, 'that': 14945, 'coach': 49, 'was': 1810, 'sending': 20, 'me': 646, 'means': 219, 'm': 1915, 'supposed': 123, 'read': 97, 'minutes': 508, 'from': 1142, 'previous': 93, 'really': 1418, 'think': 5351, 'huh': 228, 'know': 3091, 'otherwise': 97, 'just': 4630, 'saying': 167, 'secretary': 17, 'therefore': 37, 'taking': 62, 'go': 1693, 'real': 180, 'briefly': 13, 'last': 373, 'open': 185, 'them': 898, 'slowly': 3, 'no': 3134, 'wait': 118, 'not': 3373, 'you': 16049, 'how': 1500, 'very': 1663, 'high-powered': 1, 'stuff': 353, 'double-clicking': 1, 'there': 2556, 'basically': 442, 'moral': 1, 'story': 7, 'minute': 62, 'had': 646, 'meetings': 79, 'presentations': 109, 'by': 616, 'industrial': 145, 'designer': 198, 'or': 4060, 'nathan': 13, 'ron': 10, 'sarah': 23, 'can': 5493, 'do': 3352, 'sort': 780, 'limitations': 10, 're': 3069, 'operating': 33, 'with': 3492, 'excuse': 24, 'under': 171, 'risk': 15, 'd': 1191, 'be': 5672, 'looking': 320, 'some': 1832, 'various': 49, 'approaches': 1, 'were': 586, 'discussing': 22, 'essentially': 13, 'came': 101, 'conclusion': 23, 'should': 1832, 'develop': 36, 'a': 14398, 'remote': 3309, 'voice': 393, 'recognition': 634, 'i_e_': 3, 'vaguely': 2, 'non-remote': 4, 'like': 5546, 'shape': 405, 'because': 1786, 'didn': 414, 'need': 1315, 'use': 2049, 'as': 2336, 'since': 126, 'could': 1913, 'your': 1854, 'would': 2436, 'include': 110, 'mostly': 42, 'simple': 518, 'features': 265, 'television': 459, 'operation': 7, 'but': 6230, 'slide': 229, 'fold-out': 1, 'bay': 3, 'advanced': 250, 'functions': 596, 'users': 210, 'u_i_d_': 16, 'i_d_': 22, 'asked': 45, 'ahead': 76, 'start': 296, 'developing': 12, 'us': 510, 'sorted': 9, 'back': 546, 'main': 186, 'meet': 53, 'take': 544, 'away': 179, 'guys': 219, 'well': 3997, 'assembled': 2, 'said': 430, 'took': 51, 'into': 642, 'account': 52, 'lot': 651, 'things': 985, 'went': 91, 'most': 617, 'important': 536, 'consider': 82, 'are': 3194, 'decided': 161, 'touch': 192, 'screen': 762, 'see': 1269, 'opted': 2, 'large': 75, 'buttons': 2099, 'primary': 30, 'going': 940, 'on': 5178, 'off': 482, 'button': 1419, 'these': 839, 'through': 329, 'channels': 328, 'two': 1509, 'volume': 515, 'down': 650, 'those': 577, 'panel': 41, 'lots': 81, 'other': 927, 'actually': 783, 'provides': 6, 'nice': 401, 'aesthetic': 13, 'when': 1060, 'far': 167, 'visible': 35, 'light': 268, 'thing': 1471, 'multiple': 58, 'colours': 477, 'coming': 101, 'why': 354, 'fair': 47, 'enough': 252, 'course': 387, 'if': 4539, 'annoying': 39, 'people': 1441, 'function': 406, 'turned': 20, 'perfect': 59, 'talked': 73, 'quite': 610, 'bit': 874, 'interchangeable': 28, 'faces': 8, 'come': 502, 'up': 1455, 'natural': 31, 'f': 501, 'call': 111, 'fruity': 56, 'appropriate': 21, 'desirable': 2, 'regular': 149, 'product': 570, 'first': 672, 'packaging': 7, 'something': 2014, 'little': 827, 'subdued': 1, 'mm': 1274, 'kay': 568, 'an': 1463, 'option': 231, 'detector': 3, 'device': 335, 'top': 300,  ...
# 10310
# <vocalsound> Okay .
# [2, 3, 4]

# %%
max_len = 60

def vectorize_sentences(dialog, max_len):
    vectors=[]
    for utterance in dialog:
        tokens=tokenizer(utterance)
        v=vocab.forward(tokens)
        if len(v) > max_len : v = v[:max_len]
        if len(v) < max_len : #padding
            tmp = np.full(max_len, vocab['<pad>'])
            tmp[0:len(v)]=v 
            v = tmp
        vectors.append(np.array(v))
    return np.array(vectors)


trains_X = [vectorize_sentences(dialog_info[0], max_len) for dialog_info in X_train]
trains_X_types_ori = [np.array(dialog_info[1]) for dialog_info in X_train]
trains_X_types = [np.array(dialog_info[2]) for dialog_info in X_train]
trains_X_speakers = [np.array(dialog_info[3]) for dialog_info in X_train]
trains_X_indices = [np.array(dialog_info[4]) for dialog_info in X_train]
vals_X = [vectorize_sentences(dialog_info[0], max_len) for dialog_info in X_val]
vals_X_types_ori = [np.array(dialog_info[1]) for dialog_info in X_val]
vals_X_types = [np.array(dialog_info[2]) for dialog_info in X_val]
vals_X_speakers = [np.array(dialog_info[3]) for dialog_info in X_val]
vals_X_indices = [np.array(dialog_info[4]) for dialog_info in X_val]

edges_train = [np.array(dialog_info[5]) for dialog_info in X_train]
edges_val = [np.array(dialog_info[5]) for dialog_info in X_val]
edges_train_set = [torch.from_numpy(e).to(device) for e in edges_train]
edges_val_set = [torch.from_numpy(e).to(device) for e in edges_val]

trains_y = [np.array(ys).reshape(-1,1) for ys in y_train]
vals_y = [np.array(ys).reshape(-1,1) for ys in y_val]

# %%
# define batch size
batch_size = max_batch_size

# create tensor datasets
trainsets = [TensorDataset(torch.from_numpy(trains_X[i]).to(device), 
                           torch.from_numpy(trains_X_types_ori[i]).to(device), 
                           torch.from_numpy(trains_X_types[i]).to(device), 
                           torch.from_numpy(trains_X_speakers[i]).to(device), 
                           torch.from_numpy(trains_X_indices[i]).float().to(device), 
                           torch.from_numpy(trains_y[i]).float().to(device)) for i in range(len(trains_X))]
valsets = [TensorDataset(torch.from_numpy(vals_X[i]).to(device), 
                          torch.from_numpy(vals_X_types_ori[i]).to(device), 
                          torch.from_numpy(vals_X_types[i]).to(device), 
                          torch.from_numpy(vals_X_speakers[i]).to(device), 
                          torch.from_numpy(vals_X_indices[i]).float().to(device), 
                          torch.from_numpy(vals_y[i]).float().to(device)) for i in range(len(vals_X))]

# create dataloaders
train_loaders = [DataLoader(trainset, shuffle=False, batch_size=batch_size) for trainset in trainsets]
val_loaders = [DataLoader(valset, shuffle=False, batch_size=batch_size) for valset in valsets]

# %%
def train_model(model, optimizer, loss_criterion, epochs, threshold):
    history_val_f1 = []
    best_val_loss = 1.0
    for epoch in range(epochs):
        avg_loss = 0
        iter = 0
        for i, train_loader in enumerate(train_loaders):
            for (samples, types_ori, types, speakers, index, labels) in train_loader:

                # training mode
                model.train()

                # clear gradients w.r.t. parameters
                optimizer.zero_grad()

                # forward pass to get output/logits
                outputs = model(samples, types_ori, types, speakers, index, edges_train_set[i])

                # calculate Loss: softmax --> cross entropy loss
                loss = loss_criterion(outputs, labels)
                avg_loss += loss.item()
                iter += 1

                # getting gradients w.r.t. parameters
                loss.backward()

                # updating parameters
                optimizer.step()

        avg_loss /= iter

        # calculate F1-score
        model.eval()
        true_labels = []
        predicted_labels = []
        # iterate through the validation loader
        with torch.no_grad():
            val_loss = 0
            iter = 0
            for i, val_loader in enumerate(val_loaders):
                for (samples, types_ori, types, speakers, index, labels) in val_loader:
                    outputs = model(samples, types_ori, types, speakers, index, edges_val_set[i])
                    val_loss += loss_criterion(outputs, labels).item()
                    iter += 1
                    predicted_labels.extend(outputs.numpy())
                    true_labels.extend(labels.numpy())
            val_loss /= iter

        # convert predicted probabilities to binary predictions        
        predicted_labels = [1 if pred > threshold else 0 for pred in predicted_labels]

        # calculate F1 score
        f1 = f1_score(true_labels, predicted_labels)
        print(f'Validation Set Evaluation - F1 Score: {f1}, Average Train Loss: {avg_loss}, Average Val Loss: {val_loss}')

        # append to history
        history_val_f1.append(f1)

        # save model when validation loss is minimal
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            # we can load this best model on the validation set later
            torch.save(model.state_dict(), 'best_model_graph3.1.pth')
    return (history_val_f1)

# %%
def plot_f1s(f1_values):
    # Set plotting style
    #plt.style.use(('dark_background', 'bmh'))
    plt.style.use('bmh')
    plt.rc('axes', facecolor='none')
    plt.rc('figure', figsize=(16, 4))

    # Plotting loss graph
    plt.plot(f1_values, label='Validation')
    plt.title('Loss Graph')
    plt.legend()
    plt.show()


def look_parameters(mdl):
    weights = torch.Tensor().to(device)
    for param_group in list(mdl.parameters()):
        weights = torch.cat((param_group.view(-1), weights))
    ws = weights.detach().cpu().numpy()
    plt.hist(ws.reshape(-1), range=(-.5, .5), bins=501)

# %%
class DialogGNN3(nn.Module):
    def __init__(self, input_dim, embed_dim, output_dim, lstm_dim, node_dim, dropout, hidden_dim_1, hidden_dim_2, hidden_dim_3):
        super(DialogGNN3, self).__init__()

        self.hdim = hidden_dim_1
        
        self.embedding = nn.Embedding(input_dim, embed_dim)
        self.embedding_type = nn.Embedding(len(possible_types), 10)
        self.embedding_speaker = nn.Embedding(len(possible_speakers), 3)
        self.lstm1 = nn.LSTM(lstm_dim, node_dim, batch_first=True)
        self.dropout1 = nn.Dropout(dropout)

        self.conv1 = RGCNConv(node_dim, hidden_dim_1, len(possible_types),
                          num_bases=30)
        self.conv2 = RGCNConv(hidden_dim_1, hidden_dim_2, len(possible_types),
                          num_bases=30)

        self.lstm2 = nn.LSTM(node_dim, hidden_dim_3, batch_first=True)
        self.dropout2 = nn.Dropout(dropout)

        self.fc = nn.Linear(hidden_dim_3 + hidden_dim_2, output_dim)


        
    def forward(self, text, type_ori, type, speaker, index, edges):
        embedded = self.embedding(text)
        embedded = F.relu(embedded)

        indices_speaker = torch.argmax(speaker, dim=1)
        indices_type_ori = torch.argmax(type_ori, dim=1)
        embedded_speaker = self.embedding_speaker(indices_speaker)
        embedded_speaker = F.relu(embedded_speaker)
        embedded_type_ori = self.embedding_type(indices_type_ori)
        embedded_type_ori = F.relu(embedded_type_ori)

        speaker_2 = embedded_speaker.unsqueeze(1).expand(-1, max_len, -1)
        type_ori_2 = embedded_type_ori.unsqueeze(1).expand(-1, max_len, -1)
        index_2 = index.unsqueeze(1).expand(-1, max_len, -1)

        x = torch.cat((embedded, type_ori_2, speaker_2, index_2), dim=2)
        lstm_out, (hidden, cell) = self.lstm1(x)
        # lstm_out = self.dropout1(lstm_out)

        x1 = lstm_out[:, -1, :]
        x1 = self.conv1(x1, edges, type)
        x1 = F.relu(x1)
        x1 = self.conv2(x1, edges, type)
        x1 = F.relu(x1)

        x2, (hidden, cell) = self.lstm2(lstm_out)
        x2 = x2[:, -1, :]
        x2 = F.relu(x2)
        # x2 = self.dropout2(x2)

        xf = torch.cat((x1, x2), dim=1)
        xf = self.fc(xf)

        output = torch.sigmoid(xf)
        
        return output

# %%
input_dimension = len(tops) + 2 #add 2 for <unk> and <pad> symbols
embedding_dimension = 114
output_dimension = 1
num_epochs = 1000
l_rate = 0.0001
lstm_dimension = embedding_dimension + 10 + 3 + 1
node_dimension = 100
thresh = 0.3
hidden_dimension_1 = 128
hidden_dimension_2 = 128
hidden_dimension_3 = 64
dropout_rate = 0.2

gnn = DialogGNN3(input_dimension, embedding_dimension, output_dimension, lstm_dimension, node_dimension, dropout_rate, hidden_dimension_1,
                  hidden_dimension_2, hidden_dimension_3)
gnn.to(device)

criterion_fx = nn.BCELoss()

optimizer_fx = torch.optim.Adam(gnn.parameters(), lr=l_rate, weight_decay=5e-4)
# optimizer_fx = torch.optim.Adam(gnn.parameters(), lr=l_rate)

val_f1 = train_model(gnn, optimizer_fx, criterion_fx, num_epochs, thresh)

plot_f1s(val_f1)
# Out:
# Validation Set Evaluation - F1 Score: 0.3910054425665998, Average Train Loss: 0.5020439930550464, Average Val Loss: 0.46062080562114716
# Validation Set Evaluation - F1 Score: 0.3988629563135847, Average Train Loss: 0.4279401685510363, Average Val Loss: 0.4573647066950798
# Validation Set Evaluation - F1 Score: 0.40327533265097243, Average Train Loss: 0.4260742261812284, Average Val Loss: 0.45660448223352434
# Validation Set Evaluation - F1 Score: 0.4015645371577575, Average Train Loss: 0.42525726556777954, Average Val Loss: 0.4563148692250252
# Validation Set Evaluation - F1 Score: 0.4012692917928746, Average Train Loss: 0.4248114015374865, Average Val Loss: 0.45610710680484773
# Validation Set Evaluation - F1 Score: 0.39947780678851175, Average Train Loss: 0.4245259448305353, Average Val Loss: 0.4559881046414375
# Validation Set Evaluation - F1 Score: 0.39930151338766007, Average Train Loss: 0.4242931298621289, Average Val Loss: 0.4559276461601257
# Validation Set Evaluation - F1 Score: 0.39953474847339343, Average Train Loss: 0.42411905991566645, Average Val Loss: 0.45586234480142596
# Validation Set Evaluation - F1 Score: 0.39924065420560745, Average Train Loss: 0.4239872167636822, Average Val Loss: 0.4558248147368431
# Validation Set Evaluation - F1 Score: 0.40034965034965037, Average Train Loss: 0.42386286212252333, Average Val Loss: 0.455792935192585
# Validation Set Evaluation - F1 Score: 0.40023337222870475, Average Train Loss: 0.42376802029547755, Average Val Loss: 0.455781826376915
# Validation Set Evaluation - F1 Score: 0.40046941469854774, Average Train Loss: 0.4236840888277277, Average Val Loss: 0.45574012249708173
# Validation Set Evaluation - F1 Score: 0.40111420612813364, Average Train Loss: 0.42360953851179645, Average Val Loss: 0.4557251200079918
# Validation Set Evaluation - F1 Score: 0.4012327560904021, Average Train Loss: 0.42355354497959086, Average Val Loss: 0.45570058822631837
# Validation Set Evaluation - F1 Score: 0.40070817350250815, Average Train Loss: 0.42351148422662316, Average Val Loss: 0.45570231378078463
# Validation Set Evaluation - F1 Score: 0.40029585798816564, Average Train Loss: 0.4234587968169869, Average Val Loss: 0.45569437742233276
# Validation Set Evaluation - F1 Score: 0.401591043017089, Average Train Loss: 0.42340791883406703, Average Val Loss: 0.4556756168603897
# Validation Set Evaluation - F1 Score: 0.3996439697374277, Average Train Loss: 0.4233577816517322, Average Val Loss: 0.4556425392627716
# Validation Set Evaluation - F1 Score: 0.40023752969121146, Average Train Loss: 0.4233297365052359, Average Val Loss: 0.455660292506218
# Validation Set Evaluation - F1 Score: 0.39988089921095726, Average Train Loss: 0.4233008208987001, Average Val Loss: 0.45562976151704787
# Validation Set Evaluation - F1 Score: 0.4000594441967603, Average Train Loss: 0.4232551134251929, Average Val Loss: 0.45564796179533007
# Validation Set Evaluation - F1 Score: 0.40011881776325564, Average Train Loss: 0.4232303643381441, Average Val Loss: 0.45563369542360305
# Validation Set Evaluation - F1 Score: 0.39999999999999997, Average Train Loss: 0.42321424360399124, Average Val Loss: 0.4556290552020073
# Validation Set Evaluation - F1 Score: 0.3995825257193976, Average Train Loss: 0.4231899744504458, Average Val Loss: 0.45563384890556335
# Validation Set Evaluation - F1 Score: 0.3993428912783752, Average Train Loss: 0.4231651897554274, Average Val Loss: 0.45561739802360535
# Validation Set Evaluation - F1 Score: 0.39856373429084374, Average Train Loss: 0.4231421668808182, Average Val Loss: 0.45559572130441667
# Validation Set Evaluation - F1 Score: 0.39910514541387027, Average Train Loss: 0.42310104702974294, Average Val Loss: 0.45557500422000885
# Validation Set Evaluation - F1 Score: 0.39832535885167464, Average Train Loss: 0.42308667263427335, Average Val Loss: 0.45555147975683213
# Validation Set Evaluation - F1 Score: 0.3988629563135847, Average Train Loss: 0.4230512643789316, Average Val Loss: 0.4555390253663063
# Validation Set Evaluation - F1 Score: 0.3983825071139734, Average Train Loss: 0.42302143496352357, Average Val Loss: 0.4555311590433121
# Validation Set Evaluation - F1 Score: 0.39790104947526234, Average Train Loss: 0.4229949778550631, Average Val Loss: 0.45552940517663953
# Validation Set Evaluation - F1 Score: 0.3985007496251874, Average Train Loss: 0.4229607903338098, Average Val Loss: 0.45552016496658326
# Validation Set Evaluation - F1 Score: 0.39825930372148854, Average Train Loss: 0.42291594944991073, Average Val Loss: 0.4554876446723938
# Validation Set Evaluation - F1 Score: 0.39838129496402874, Average Train Loss: 0.42288156492369516, Average Val Loss: 0.45546727925539016
# Validation Set Evaluation - F1 Score: 0.39820627802690584, Average Train Loss: 0.42285238496668925, Average Val Loss: 0.455447781085968
# Validation Set Evaluation - F1 Score: 0.39874458227469733, Average Train Loss: 0.4228158120985155, Average Val Loss: 0.4554146707057953
# Validation Set Evaluation - F1 Score: 0.39832785906240675, Average Train Loss: 0.42276846588432015, Average Val Loss: 0.4553674295544624
# Validation Set Evaluation - F1 Score: 0.40035772842450446, Average Train Loss: 0.4227356388197317, Average Val Loss: 0.45534303337335585
# Validation Set Evaluation - F1 Score: 0.4008375710439725, Average Train Loss: 0.42267117020371675, Average Val Loss: 0.45530321896076204
# Validation Set Evaluation - F1 Score: 0.40178837555886737, Average Train Loss: 0.42261418274470736, Average Val Loss: 0.4552917301654816
# Validation Set Evaluation - F1 Score: 0.40113331345064124, Average Train Loss: 0.42253801071798647, Average Val Loss: 0.4552036628127098
# Validation Set Evaluation - F1 Score: 0.4006051437216339, Average Train Loss: 0.42244530691728965, Average Val Loss: 0.4551099672913551
# Validation Set Evaluation - F1 Score: 0.4004282655246253, Average Train Loss: 0.42221841990173636, Average Val Loss: 0.45472527891397474
# Validation Set Evaluation - F1 Score: 0.4252715312834634, Average Train Loss: 0.4207886082011384, Average Val Loss: 0.450392609834671
# Validation Set Evaluation - F1 Score: 0.4832904884318766, Average Train Loss: 0.4109601510035527, Average Val Loss: 0.4313417747616768
# Validation Set Evaluation - F1 Score: 0.514041514041514, Average Train Loss: 0.3859863970186803, Average Val Loss: 0.40917428880929946
# Validation Set Evaluation - F1 Score: 0.5167449613577815, Average Train Loss: 0.37402314450833707, Average Val Loss: 0.4026340365409851
# Validation Set Evaluation - F1 Score: 0.5314379442318207, Average Train Loss: 0.3701530404679187, Average Val Loss: 0.39695820957422256
# Validation Set Evaluation - F1 Score: 0.5318383167220376, Average Train Loss: 0.3664477484953868, Average Val Loss: 0.3947469264268875
# Validation Set Evaluation - F1 Score: 0.5335183900069397, Average Train Loss: 0.3638114571184307, Average Val Loss: 0.39292067736387254
# Validation Set Evaluation - F1 Score: 0.5360910605219322, Average Train Loss: 0.36188943316410116, Average Val Loss: 0.3915844693779945
# Validation Set Evaluation - F1 Score: 0.5377939529675252, Average Train Loss: 0.360225658138077, Average Val Loss: 0.39044593572616576
# Validation Set Evaluation - F1 Score: 0.54002828854314, Average Train Loss: 0.35880042902835, Average Val Loss: 0.3894415408372879
# Validation Set Evaluation - F1 Score: 0.5428816466552315, Average Train Loss: 0.3575016908444367, Average Val Loss: 0.38853906393051146
# Validation Set Evaluation - F1 Score: 0.544221613042851, Average Train Loss: 0.3563003582613809, Average Val Loss: 0.38764462172985076
# Validation Set Evaluation - F1 Score: 0.5452695829094609, Average Train Loss: 0.355207567091112, Average Val Loss: 0.38677736967802046
# Validation Set Evaluation - F1 Score: 0.5474844135131216, Average Train Loss: 0.3541219731816998, Average Val Loss: 0.38553584218025205
# Validation Set Evaluation - F1 Score: 0.5489162272993555, Average Train Loss: 0.35301852516539683, Average Val Loss: 0.3851660951972008
# Validation Set Evaluation - F1 Score: 0.550631053712944, Average Train Loss: 0.3521011376922781, Average Val Loss: 0.38390932977199554
# Validation Set Evaluation - F1 Score: 0.5534883720930233, Average Train Loss: 0.3510399723981882, Average Val Loss: 0.3822600290179253
# Validation Set Evaluation - F1 Score: 0.5522212415416299, Average Train Loss: 0.34999185994073945, Average Val Loss: 0.3822973906993866
# Validation Set Evaluation - F1 Score: 0.5559105431309904, Average Train Loss: 0.34932832710154643, Average Val Loss: 0.3806562125682831
# Validation Set Evaluation - F1 Score: 0.5584037285173317, Average Train Loss: 0.34844265491157383, Average Val Loss: 0.3800850287079811
# Validation Set Evaluation - F1 Score: 0.5574057843996494, Average Train Loss: 0.34784161967116517, Average Val Loss: 0.37973700612783434
# Validation Set Evaluation - F1 Score: 0.5583162817889505, Average Train Loss: 0.34722547271809023, Average Val Loss: 0.37902298718690874
# Validation Set Evaluation - F1 Score: 0.5586085939783688, Average Train Loss: 0.3466536201439895, Average Val Loss: 0.37866192758083345
# Validation Set Evaluation - F1 Score: 0.5573962762058349, Average Train Loss: 0.3459601537747817, Average Val Loss: 0.3784570977091789
# Validation Set Evaluation - F1 Score: 0.5596050529984028, Average Train Loss: 0.34530912881547754, Average Val Loss: 0.3771814629435539
# Validation Set Evaluation - F1 Score: 0.5594790159189581, Average Train Loss: 0.34478576713568204, Average Val Loss: 0.37655849754810333
# Validation Set Evaluation - F1 Score: 0.5614035087719299, Average Train Loss: 0.3443357547769299, Average Val Loss: 0.3751892387866974
# Validation Set Evaluation - F1 Score: 0.561289410434045, Average Train Loss: 0.34376765458614794, Average Val Loss: 0.3742907032370567
# Validation Set Evaluation - F1 Score: 0.5622263031501625, Average Train Loss: 0.34332994594202415, Average Val Loss: 0.37388484328985216
# Validation Set Evaluation - F1 Score: 0.562340244248793, Average Train Loss: 0.34289491466887584, Average Val Loss: 0.37376766502857206
# Validation Set Evaluation - F1 Score: 0.5629820051413882, Average Train Loss: 0.3424578487098991, Average Val Loss: 0.3737747326493263
# Validation Set Evaluation - F1 Score: 0.5641539121727935, Average Train Loss: 0.3420537344434045, Average Val Loss: 0.3735885262489319
# Validation Set Evaluation - F1 Score: 0.5650429799426935, Average Train Loss: 0.34173084060093023, Average Val Loss: 0.37327981293201445
# Validation Set Evaluation - F1 Score: 0.5648547598504459, Average Train Loss: 0.3414039085437725, Average Val Loss: 0.373099659383297
# Validation Set Evaluation - F1 Score: 0.564885496183206, Average Train Loss: 0.3411335776765625, Average Val Loss: 0.3728383302688599
# Validation Set Evaluation - F1 Score: 0.5658255227108868, Average Train Loss: 0.34085980541520305, Average Val Loss: 0.3726546823978424
# Validation Set Evaluation - F1 Score: 0.5655252131194913, Average Train Loss: 0.34060282269855596, Average Val Loss: 0.37257424294948577
# Validation Set Evaluation - F1 Score: 0.5661849710982658, Average Train Loss: 0.34037390912508037, Average Val Loss: 0.37245645374059677
# Validation Set Evaluation - F1 Score: 0.5659887494591086, Average Train Loss: 0.34015794930519994, Average Val Loss: 0.3721650272607803
# Validation Set Evaluation - F1 Score: 0.5670221965984433, Average Train Loss: 0.3399689652315982, Average Val Loss: 0.372062911093235
# Validation Set Evaluation - F1 Score: 0.5677697841726619, Average Train Loss: 0.3397713963474546, Average Val Loss: 0.3717185601592064
# Validation Set Evaluation - F1 Score: 0.5682210708117444, Average Train Loss: 0.33957896217123257, Average Val Loss: 0.3715636685490608
# Validation Set Evaluation - F1 Score: 0.5672202166064982, Average Train Loss: 0.3393963600520964, Average Val Loss: 0.37170801162719724
# Validation Set Evaluation - F1 Score: 0.5667291877074015, Average Train Loss: 0.33922543308951636, Average Val Loss: 0.3715276807546616
# Validation Set Evaluation - F1 Score: 0.5660322952710496, Average Train Loss: 0.3390863175903048, Average Val Loss: 0.3714092209935188
# Validation Set Evaluation - F1 Score: 0.5681948424068768, Average Train Loss: 0.3389069857922467, Average Val Loss: 0.3710051700472832
# Validation Set Evaluation - F1 Score: 0.5672455863355821, Average Train Loss: 0.3387178558033782, Average Val Loss: 0.3709919184446335
# Validation Set Evaluation - F1 Score: 0.5667574931880109, Average Train Loss: 0.3385137038958537, Average Val Loss: 0.3708358407020569
# Validation Set Evaluation - F1 Score: 0.5678658449190196, Average Train Loss: 0.33835088335848473, Average Val Loss: 0.37068772614002227
# Validation Set Evaluation - F1 Score: 0.5673656995116346, Average Train Loss: 0.33820872686126013, Average Val Loss: 0.3707436382770538
# Validation Set Evaluation - F1 Score: 0.5681557846506301, Average Train Loss: 0.33805283439623846, Average Val Loss: 0.37055824100971224
# Validation Set Evaluation - F1 Score: 0.5684902156834739, Average Train Loss: 0.3378866080726896, Average Val Loss: 0.37032614946365355
# Validation Set Evaluation - F1 Score: 0.5673718585829902, Average Train Loss: 0.3377130908238423, Average Val Loss: 0.36999701410532
# Validation Set Evaluation - F1 Score: 0.5673919186210794, Average Train Loss: 0.33751031291949285, Average Val Loss: 0.3695966452360153
# Validation Set Evaluation - F1 Score: 0.568169014084507, Average Train Loss: 0.33734396912834863, Average Val Loss: 0.36941562592983246
# Validation Set Evaluation - F1 Score: 0.5676818950930625, Average Train Loss: 0.33727052730399293, Average Val Loss: 0.3694185376167297
# Validation Set Evaluation - F1 Score: 0.5688513037350246, Average Train Loss: 0.33706354378879844, Average Val Loss: 0.36926934123039246
# Validation Set Evaluation - F1 Score: 0.568507738179753, Average Train Loss: 0.33690431636649293, Average Val Loss: 0.3694013565778732
# Validation Set Evaluation - F1 Score: 0.5696022727272728, Average Train Loss: 0.3367381471318084, Average Val Loss: 0.3693427056074142
# Validation Set Evaluation - F1 Score: 0.5698371893744645, Average Train Loss: 0.3365551010741816, Average Val Loss: 0.36949307918548585
# Validation Set Evaluation - F1 Score: 0.5701641684511064, Average Train Loss: 0.3363348845537607, Average Val Loss: 0.369377039372921
# Validation Set Evaluation - F1 Score: 0.5699481865284974, Average Train Loss: 0.3362460397667699, Average Val Loss: 0.3697448313236237
# Validation Set Evaluation - F1 Score: 0.5697142857142857, Average Train Loss: 0.3360709279001533, Average Val Loss: 0.3692998707294464
# Validation Set Evaluation - F1 Score: 0.5687011859994215, Average Train Loss: 0.33606539918230727, Average Val Loss: 0.3701863050460815
# Validation Set Evaluation - F1 Score: 0.5711041725801873, Average Train Loss: 0.3360768359202843, Average Val Loss: 0.3689204826951027
# Validation Set Evaluation - F1 Score: 0.5717880609534461, Average Train Loss: 0.3359562280503186, Average Val Loss: 0.3684218019247055
# Validation Set Evaluation - F1 Score: 0.5726687202464295, Average Train Loss: 0.3361622497632906, Average Val Loss: 0.36824643015861513
# Validation Set Evaluation - F1 Score: 0.5708655876143561, Average Train Loss: 0.3355142454822342, Average Val Loss: 0.36831811666488645
# Validation Set Evaluation - F1 Score: 0.574323386537127, Average Train Loss: 0.33571970191868866, Average Val Loss: 0.3678410887718201
# Validation Set Evaluation - F1 Score: 0.5725931131412508, Average Train Loss: 0.33511646691854896, Average Val Loss: 0.3680113986134529
# Validation Set Evaluation - F1 Score: 0.5735172413793104, Average Train Loss: 0.3349108649538709, Average Val Loss: 0.36739541888237
# Validation Set Evaluation - F1 Score: 0.5732200083600391, Average Train Loss: 0.33471305590945405, Average Val Loss: 0.36769740134477613
# Validation Set Evaluation - F1 Score: 0.5721583652618135, Average Train Loss: 0.33486635692707906, Average Val Loss: 0.3677616313099861
# Validation Set Evaluation - F1 Score: 0.5724812243162817, Average Train Loss: 0.3343550783473176, Average Val Loss: 0.3678114652633667
# Validation Set Evaluation - F1 Score: 0.5735963581183613, Average Train Loss: 0.3342415396269266, Average Val Loss: 0.36704163551330565
# Validation Set Evaluation - F1 Score: 0.5722323814882543, Average Train Loss: 0.334247285282457, Average Val Loss: 0.36774266958236695
# Validation Set Evaluation - F1 Score: 0.5743290223890976, Average Train Loss: 0.3341678588034271, Average Val Loss: 0.3673088297247887
# Validation Set Evaluation - F1 Score: 0.5736961451247166, Average Train Loss: 0.333919825104924, Average Val Loss: 0.36749368011951444
# Validation Set Evaluation - F1 Score: 0.5729957805907172, Average Train Loss: 0.3338153085538319, Average Val Loss: 0.3675744250416756
# Validation Set Evaluation - F1 Score: 0.5741176470588235, Average Train Loss: 0.3337672277317419, Average Val Loss: 0.367038357257843
# Validation Set Evaluation - F1 Score: 0.5742327896046446, Average Train Loss: 0.3336594964002634, Average Val Loss: 0.3669006645679474
# Validation Set Evaluation - F1 Score: 0.5749480968858132, Average Train Loss: 0.3335940481780411, Average Val Loss: 0.3664815440773964
# Validation Set Evaluation - F1 Score: 0.5752840909090909, Average Train Loss: 0.33309654756025836, Average Val Loss: 0.3667486757040024
# Validation Set Evaluation - F1 Score: 0.5752187411797911, Average Train Loss: 0.3327455183902344, Average Val Loss: 0.3667128399014473
# Validation Set Evaluation - F1 Score: 0.5738145789101204, Average Train Loss: 0.33292830861234046, Average Val Loss: 0.36685425639152525
# Validation Set Evaluation - F1 Score: 0.5732448085887838, Average Train Loss: 0.3328563487761981, Average Val Loss: 0.36727383732795715
# Validation Set Evaluation - F1 Score: 0.5738022708391028, Average Train Loss: 0.3327517807483673, Average Val Loss: 0.36664522290229795
# Validation Set Evaluation - F1 Score: 0.5741003117030321, Average Train Loss: 0.33285856150187454, Average Val Loss: 0.3670641347765923
# Validation Set Evaluation - F1 Score: 0.5748218527315915, Average Train Loss: 0.33231586682332026, Average Val Loss: 0.36638207286596297
# Validation Set Evaluation - F1 Score: 0.5742181972548465, Average Train Loss: 0.3326052160232098, Average Val Loss: 0.3667424365878105
# Validation Set Evaluation - F1 Score: 0.5732122587968218, Average Train Loss: 0.33226560056209564, Average Val Loss: 0.3670141831040382
# Validation Set Evaluation - F1 Score: 0.5739570164348925, Average Train Loss: 0.33208214230351635, Average Val Loss: 0.3663229629397392
# Validation Set Evaluation - F1 Score: 0.5733201859416819, Average Train Loss: 0.3321914430949595, Average Val Loss: 0.36638266742229464
# Validation Set Evaluation - F1 Score: 0.5746089897139637, Average Train Loss: 0.3319595903158188, Average Val Loss: 0.36639441549777985
# Validation Set Evaluation - F1 Score: 0.5748865355521937, Average Train Loss: 0.3314879577268254, Average Val Loss: 0.3656847432255745
# Validation Set Evaluation - F1 Score: 0.5750879662209712, Average Train Loss: 0.3316673164243822, Average Val Loss: 0.3659562185406685
# Validation Set Evaluation - F1 Score: 0.5758419148344002, Average Train Loss: 0.331460980045331, Average Val Loss: 0.36548061966896056
# Validation Set Evaluation - F1 Score: 0.5752249134948098, Average Train Loss: 0.33091808158855934, Average Val Loss: 0.36535010039806365
# Validation Set Evaluation - F1 Score: 0.5736541939073584, Average Train Loss: 0.3309541590415038, Average Val Loss: 0.36520209312438967
# Validation Set Evaluation - F1 Score: 0.5768756000548622, Average Train Loss: 0.3306602125431036, Average Val Loss: 0.36510736793279647
# Validation Set Evaluation - F1 Score: 0.5743262017227008, Average Train Loss: 0.33040345256978815, Average Val Loss: 0.36493501961231234
# Validation Set Evaluation - F1 Score: 0.5774529097554119, Average Train Loss: 0.33045723008645045, Average Val Loss: 0.36479500830173495
# Validation Set Evaluation - F1 Score: 0.5749825296995108, Average Train Loss: 0.3299254931799777, Average Val Loss: 0.36486992985010147
# Validation Set Evaluation - F1 Score: 0.5717216117216116, Average Train Loss: 0.33074578468675736, Average Val Loss: 0.36650959104299546
# Validation Set Evaluation - F1 Score: 0.5730240549828179, Average Train Loss: 0.33068491847484144, Average Val Loss: 0.3667218089103699
# Validation Set Evaluation - F1 Score: 0.5769867549668873, Average Train Loss: 0.33018964916080623, Average Val Loss: 0.364979749917984
# Validation Set Evaluation - F1 Score: 0.5755838344287513, Average Train Loss: 0.3300781683488326, Average Val Loss: 0.36479455083608625
# Validation Set Evaluation - F1 Score: 0.5766955564726923, Average Train Loss: 0.3295775026857079, Average Val Loss: 0.36453951001167295
# Validation Set Evaluation - F1 Score: 0.5777654560576656, Average Train Loss: 0.3296892966155882, Average Val Loss: 0.36460513472557066
# Validation Set Evaluation - F1 Score: 0.578003670760977, Average Train Loss: 0.329346138742063, Average Val Loss: 0.3645656302571297
# Validation Set Evaluation - F1 Score: 0.576275979075357, Average Train Loss: 0.32909528040266656, Average Val Loss: 0.3646353781223297
# Validation Set Evaluation - F1 Score: 0.5758754863813229, Average Train Loss: 0.3290939379435081, Average Val Loss: 0.36431522518396375
# Validation Set Evaluation - F1 Score: 0.5747259088286208, Average Train Loss: 0.3292937942526557, Average Val Loss: 0.365202496945858
# Validation Set Evaluation - F1 Score: 0.5757921781330287, Average Train Loss: 0.32904571894701423, Average Val Loss: 0.3651126101613045
# Validation Set Evaluation - F1 Score: 0.5761410493388313, Average Train Loss: 0.3288497052022389, Average Val Loss: 0.365136182308197
# Validation Set Evaluation - F1 Score: 0.5772017837235228, Average Train Loss: 0.3289555849192978, Average Val Loss: 0.3644848272204399
# Validation Set Evaluation - F1 Score: 0.5767389467755561, Average Train Loss: 0.3284113105241354, Average Val Loss: 0.36423110514879226
# Validation Set Evaluation - F1 Score: 0.5770052714061832, Average Train Loss: 0.32828470251776953, Average Val Loss: 0.3645265504717827
# Validation Set Evaluation - F1 Score: 0.5749295774647888, Average Train Loss: 0.32838342329124354, Average Val Loss: 0.36503215581178666
# Validation Set Evaluation - F1 Score: 0.576223381751516, Average Train Loss: 0.3285057529226526, Average Val Loss: 0.36455019414424894
# Validation Set Evaluation - F1 Score: 0.5758044119713361, Average Train Loss: 0.3279740225959134, Average Val Loss: 0.3639803186058998
# Validation Set Evaluation - F1 Score: 0.5791868069377311, Average Train Loss: 0.3282425206202965, Average Val Loss: 0.36444222629070283
# Validation Set Evaluation - F1 Score: 0.5783707865168539, Average Train Loss: 0.3276043383332042, Average Val Loss: 0.3640998214483261
# Validation Set Evaluation - F1 Score: 0.5786859656591458, Average Train Loss: 0.327946679739209, Average Val Loss: 0.36431249380111697
# Validation Set Evaluation - F1 Score: 0.5780298837852795, Average Train Loss: 0.3281058951631769, Average Val Loss: 0.3643016263842583
# Validation Set Evaluation - F1 Score: 0.5779488589496838, Average Train Loss: 0.32741017484819734, Average Val Loss: 0.363431042432785
# Validation Set Evaluation - F1 Score: 0.5799972485899023, Average Train Loss: 0.32705734186358265, Average Val Loss: 0.36306582689285277
# Validation Set Evaluation - F1 Score: 0.5789109048080919, Average Train Loss: 0.32662121990284365, Average Val Loss: 0.36321194022893905

# %%
best_model = DialogGNN3(input_dimension, embedding_dimension, output_dimension, lstm_dimension, node_dimension, dropout_rate, hidden_dimension_1, 
                        hidden_dimension_2, hidden_dimension_3)
best_model.load_state_dict(torch.load('best_model_graph3.1.pth'))

test_labels = {}

for transcription_id in test_set:
    utterances = []
    speakers = []
    types = []
    index = []
    transcription_edges = []
    with open(path_to_test / f"{transcription_id}.txt", 'r') as file:
        transcription_edges.append("0 Beginning 0\n")
        for line in file:
            transcription_edges.append(line)
    tmp_types = [d.split(" ")[1] for d in transcription_edges]
    tmp_edges_start = [int(d.split(" ")[0]) for d in transcription_edges]
    tmp_edges_end = [int(d.split(" ")[2][:-1]) for d in transcription_edges]
    edges = [tmp_edges_start, tmp_edges_end]
    
    types_ori = [[1*(t==tmp_t) for t in possible_types] for tmp_t in tmp_types]
    types = [possible_types.index(tmp_t) for tmp_t in tmp_types]

    with open(path_to_test / f"{transcription_id}.json", "r") as file:
        transcription = json.load(file)
    
    for utterance in transcription:
        speakers.append([1*(speaker==utterance["speaker"]) for speaker in possible_speakers])
        utterances.append(utterance["text"])
        index.append([utterance["index"]])

    index = np.array(index)/len(index)
    max_batch_size = max(max_batch_size, len(utterances))
    dialog_dataset = [utterances, types_ori, types, speakers, index, edges]


    tests_data_X = vectorize_sentences(dialog_dataset[0], max_len)
    tests_data_X_types_ori = np.array(dialog_dataset[1])
    tests_data_X_types = np.array(dialog_dataset[2])
    tests_data_X_speakers = np.array(dialog_dataset[3])
    tests_data_X_indices = np.array(dialog_dataset[4])

    edges_test_test = np.array(dialog_dataset[5])
    edges_test_set_test = torch.from_numpy(edges_test_test).to(device)

    test_dataset = TensorDataset(torch.from_numpy(tests_data_X).to(device), 
                                 torch.from_numpy(tests_data_X_types_ori).to(device), 
                                 torch.from_numpy(tests_data_X_types).to(device), 
                                 torch.from_numpy(tests_data_X_speakers).to(device), 
                                 torch.from_numpy(tests_data_X_indices).float().to(device))

    test_data_loader = DataLoader(test_dataset, shuffle=False, batch_size=max_batch_size)

    best_model.eval()
    predicted_labels = []
    with torch.no_grad():
        for (samples, types_ori, types, speakers, index) in test_data_loader:
            outputs = best_model(samples, types_ori, types, speakers, index, edges_test_set_test)
            predicted_labels.extend(outputs.numpy())

    predicted_labels = [1 if pred > thresh else 0 for pred in predicted_labels]
    test_labels[transcription_id] = predicted_labels

with open("test_labels_graph3_baseline.json", "w") as file:
    json.dump(test_labels, file, indent=4)
